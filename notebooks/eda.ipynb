# %% [markdown]
# # Fake News Detection - Exploratory Data Analysis (EDA)
#
# **MCA Major Project 2026**
#
# This notebook performs EDA on the Fake News dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import warnings
warnings.filterwarnings('ignore')
plt.style.use('ggplot')
sns.set_palette('viridis')
print('Libraries imported successfully!')

# %% [markdown]
# ## 1. Load Dataset

# %%
df = pd.read_csv('../data/train.csv')
print(f'Dataset Shape: {df.shape}')
print(f'Columns: {list(df.columns)}')
df.head()

# %% [markdown]
# ## 2. Basic Info

# %%
print('=== Dataset Info ===')
print(df.info())
print('
=== Stats ===')
df.describe()

# %%
print('=== Missing Values ===')
print(df.isnull().sum())

# %% [markdown]
# ## 3. Label Distribution

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
sns.countplot(x='label', data=df, ax=axes[0], palette=['#2ecc71','#e74c3c'])
axes[0].set_title('Label Distribution')
axes[0].set_xticklabels(['Real(0)','Fake(1)'])
df['label'].value_counts().plot.pie(autopct='%1.1f%%', ax=axes[1], colors=['#2ecc71','#e74c3c'], labels=['Real','Fake'])
axes[1].set_title('Label %')
axes[1].set_ylabel('')
plt.tight_layout()
plt.savefig('../reports/label_distribution.png', dpi=150)
plt.show()

# %% [markdown]
# ## 4. Text Length Analysis

# %%
df['text_length'] = df['text'].astype(str).apply(len)
df['word_count'] = df['text'].astype(str).apply(lambda x: len(x.split()))
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
for label, color, name in [(0,'#2ecc71','Real'),(1,'#e74c3c','Fake')]:
    subset = df[df['label']==label]
    axes[0].hist(subset['text_length'], bins=50, alpha=0.6, color=color, label=name)
    axes[1].hist(subset['word_count'], bins=50, alpha=0.6, color=color, label=name)
axes[0].set_title('Text Length Distribution')
axes[0].legend()
axes[1].set_title('Word Count Distribution')
axes[1].legend()
plt.tight_layout()
plt.savefig('../reports/text_length_distribution.png', dpi=150)
plt.show()

# %% [markdown]
# ## 5. Word Clouds

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
real_text = ' '.join(df[df['label']==0]['text'].astype(str).tolist())
wc_real = WordCloud(width=800, height=400, background_color='white', colormap='Greens', max_words=100).generate(real_text)
axes[0].imshow(wc_real, interpolation='bilinear')
axes[0].set_title('Word Cloud - REAL News')
axes[0].axis('off')
fake_text = ' '.join(df[df['label']==1]['text'].astype(str).tolist())
wc_fake = WordCloud(width=800, height=400, background_color='white', colormap='Reds', max_words=100).generate(fake_text)
axes[1].imshow(wc_fake, interpolation='bilinear')
axes[1].set_title('Word Cloud - FAKE News')
axes[1].axis('off')
plt.tight_layout()
plt.savefig('../reports/word_clouds.png', dpi=150)
plt.show()

# %% [markdown]
# ## 6. Summary
#
# Key findings:
# - Dataset has both real and fake news
# - Different vocabulary patterns between real and fake
# - Ready for ML classification
#
# **Next:** Run `python main.py` to train models
